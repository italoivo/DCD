# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import dynamic_louvain
from multiprocessing import Pool
import bct
from numpy.random import default_rng
import pickle
import parameter_search

# %%
model_list = ['StdGrow','StdMerge','StdMixed']

# %%
def load_data(prefix):
    comms_filename = prefix + '.tcomms'
    comms_data = np.loadtxt(comms_filename,delimiter=' ')
    time_layers = list(set(comms_data[:,0]))
    comm_structure = []
    for i in time_layers:
        time_layer_i = comms_data[comms_data[:,0]==i]
        time_layer_i = time_layer_i[time_layer_i[:, 1].argsort()]
        comm_structure.append(time_layer_i[:,2])
    comm_structure = np.transpose(np.array(comm_structure))
    number_of_nodes,_ = comm_structure.shape

    
    graph_filename = prefix + '.tgraph'
    graph_data = np.loadtxt(graph_filename,delimiter=' ')
    time_layers = list(set(graph_data[:,3]))
    adj_ijl = []
    for i in time_layers:
        time_layer_i = graph_data[graph_data[:,3]==i]
        links = time_layer_i[:,0:2]
        edges = [(i,j) for i,j in links]
        G = nx.from_edgelist(edges)
        adj_matrix = nx.to_numpy_array(G,nodelist=list(range(number_of_nodes)))
        adj_ijl.append(adj_matrix)
    adj_ijl = np.array(adj_ijl)
    
    comm_structure = np.transpose(comm_structure)

    return adj_ijl,comm_structure

# %%
def save_obj(obj, name ):
    with open(name, 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %%
for model in model_list:
    adj_ijl, comm_structure = load_data(model)
    plt.imshow(np.transpose(comm_structure),aspect='auto',cmap='Set2')
    plt.xlabel('Time')
    plt.ylabel('Node')
    plt.show()

# %%
model = 'StdGrow'
adj_ijl, comm_structure = load_data(model)

plt.imshow(np.transpose(comm_structure),aspect='auto',cmap='Set2')
plt.show()

# %%
for sample in range(20):
    output_filename = 'StdGrow_search' + str(sample) + '.pck'
    search_output = parameter_search.parameter_search([adj_ijl],0.2,2.0,0.2,1.0,3)
    save_obj(search_output, output_filename)
    print(output_filename + ' saved.')
# Out:
# StdGrow_search0.pck saved.
# StdGrow_search1.pck saved.
# StdGrow_search2.pck saved.
# StdGrow_search3.pck saved.
# StdGrow_search4.pck saved.
# StdGrow_search5.pck saved.
# StdGrow_search6.pck saved.
# StdGrow_search7.pck saved.
# StdGrow_search8.pck saved.
# StdGrow_search9.pck saved.
# StdGrow_search10.pck saved.
# StdGrow_search11.pck saved.
# StdGrow_search12.pck saved.
# StdGrow_search13.pck saved.
# StdGrow_search14.pck saved.
# StdGrow_search15.pck saved.
# StdGrow_search16.pck saved.
# StdGrow_search17.pck saved.
# StdGrow_search18.pck saved.
# StdGrow_search19.pck saved.

# %%
model = 'StdMerge'
adj_ijl, comm_structure = load_data(model)

plt.imshow(np.transpose(comm_structure),aspect='auto',cmap='Set2')
plt.show()

# %%
for sample in range(20):
    output_filename = 'StdMerge_search' + str(sample) + '.pck'
    search_output = parameter_search.parameter_search([adj_ijl],0.2,2.0,0.2,1.0,3)
    save_obj(search_output, output_filename)
    print(output_filename + ' saved.')
# Out:
# C:\Users\usr1\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\usr1\anaconda3\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\usr1\anaconda3\lib\site-packages\numpy\lib\histograms.py:906: RuntimeWarning: invalid value encountered in true_divide
#   return n/db/n.sum(), bin_edges
# StdMerge_search0.pck saved.
# StdMerge_search1.pck saved.
# StdMerge_search2.pck saved.
# StdMerge_search3.pck saved.
# StdMerge_search4.pck saved.
# StdMerge_search5.pck saved.
# StdMerge_search6.pck saved.
# StdMerge_search7.pck saved.
# StdMerge_search8.pck saved.
# StdMerge_search9.pck saved.
# StdMerge_search10.pck saved.
# StdMerge_search11.pck saved.
# StdMerge_search12.pck saved.
# StdMerge_search13.pck saved.
# StdMerge_search14.pck saved.
# StdMerge_search15.pck saved.
# StdMerge_search16.pck saved.
# StdMerge_search17.pck saved.
# StdMerge_search18.pck saved.
# StdMerge_search19.pck saved.

# %%
model = 'StdMixed'
adj_ijl, comm_structure = load_data(model)

plt.imshow(np.transpose(comm_structure),aspect='auto',cmap='Set2')
plt.show()

# %%
for sample in range(20):
    output_filename = 'StdMixed_search' + str(sample) + '.pck'
    search_output = parameter_search.parameter_search([adj_ijl],0.2,2.0,0.2,1.0,3)
    save_obj(search_output, output_filename)
    print(output_filename + ' saved.')
# Out:
# StdMixed_search10.pck saved.
# StdMixed_search11.pck saved.
# StdMixed_search12.pck saved.
# StdMixed_search13.pck saved.
# StdMixed_search14.pck saved.
# StdMixed_search15.pck saved.
# StdMixed_search16.pck saved.
# StdMixed_search17.pck saved.
# StdMixed_search18.pck saved.
# StdMixed_search19.pck saved.
